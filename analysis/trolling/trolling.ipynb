# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/home/gbemike/Documents/github/GrokResearch/outputs/trolling_analysis_results/merged_results.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165243 entries, 0 to 165242
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   conversationId                 47329 non-null   float64
#  1   is_trolling                    163612 non-null  object
#  2   trolling_confidence            163603 non-null  float64
#  3   trolling_intensity             163464 non-null  float64
#  4   topic                          163611 non-null  object
#  5   trolling_topic                 153542 non-null  object
#  6   troll_recognition_type         153542 non-null  object
#  7   troll_recognition_confidence   153542 non-null  float64
#  8   troll_recognition_explanation  153542 non-null  object
#  9   trolling_category_type         153542 non-null  object
#  10  trolling_category_confidence   153542 non-null  float64
#  11  trolling_category_explanation  153542 non-null  object
# ...

# %%
df.head(20)
# Out:
#     conversationId is_trolling  trolling_confidence  trolling_intensity  \
# 0              NaN          no                  5.0                 1.0
# 1     1.624387e+18         yes                  5.0                 4.0
# 2              NaN          no                  5.0                 1.0
# 3     1.842942e+18         yes                  5.0                 3.0
# 4              NaN          no                  5.0                 1.0
# 5              NaN          no                  5.0                 1.0
# 6     1.885725e+18         yes                  5.0                 3.0
# 7              NaN          no                  5.0                 1.0
# 8              NaN          no                  5.0                 1.0
# 9     1.895454e+18         yes                  3.0                 2.0
# 10    1.896464e+18         yes                  5.0                 4.0
# 11             NaN          no                  5.0                 1.0
# ...

# %%
df['is_trolling'].value_counts()
# Out:
# is_trolling
# no           110647
# yes           37868
# uncertain     15097
# Name: count, dtype: int64

# %%
yes = df[df['is_trolling'] == 'yes']

# %%
yes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1590 entries, 154217 to 165242
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     1590 non-null   int64
#  1   conversationId                 1590 non-null   float64
#  2   is_trolling                    1590 non-null   object
#  3   trolling_confidence            1590 non-null   float64
#  4   trolling_intensity             1590 non-null   float64
#  5   topic                          1590 non-null   object
#  6   trolling_topic                 1589 non-null   object
#  7   troll_recognition_type         1589 non-null   object
#  8   troll_recognition_confidence   1589 non-null   float64
#  9   troll_recognition_explanation  1589 non-null   object
#  10  trolling_category_type         1589 non-null   object
#  11  trolling_category_confidence   1589 non-null   float64
# ...

# %%
yes
# Out:
#         Unnamed: 0  conversationId is_trolling  trolling_confidence  \
# 154217      154217    1.908036e+18         yes                  5.0
# 154234      154234    1.908049e+18         yes                  4.0
# 154235      154235    1.908050e+18         yes                  4.0
# 154238      154238    1.908052e+18         yes                  5.0
# 154269      154269    1.908077e+18         yes                  4.0
# ...            ...             ...         ...                  ...
# 165216      165216    1.975259e+18         yes                  5.0
# 165222      165222    1.975259e+18         yes                  5.0
# 165230      165230    1.975259e+18         yes                  5.0
# 165235      165235    1.975259e+18         yes                  5.0
# 165242      165242    1.975260e+18         yes                  4.0
#
#         trolling_intensity                         topic  \
# 154217                 4.0      using_offensive_language
# ...
