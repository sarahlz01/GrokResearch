# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/home/gbemike/Documents/github/GrokResearch/outputs/trolling_analysis_results/trolling_merged_results.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38039 entries, 0 to 38038
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   conversationId                 38039 non-null  int64
#  1   is_trolling                    38039 non-null  object
#  2   trolling_confidence            38039 non-null  int64
#  3   trolling_intensity             38039 non-null  int64
#  4   topic                          38038 non-null  object
#  5   trolling_topic                 35797 non-null  object
#  6   troll_recognition_type         35797 non-null  object
#  7   troll_recognition_confidence   35797 non-null  float64
#  8   troll_recognition_explanation  35797 non-null  object
#  9   trolling_category_type         35797 non-null  object
#  10  trolling_category_confidence   35797 non-null  float64
#  11  trolling_category_explanation  35797 non-null  object
# ...

# %%
df.head(20)
# Out:
#          conversationId is_trolling  trolling_confidence  trolling_intensity  \
# 0   1108705044143046658         yes                    5                   4
# 1   1388945117743038467         yes                    4                   3
# 2   1532010283962613762         yes                    4                   3
# 3   1901027489440559192         yes                    5                   4
# 4   1905361754760020138         yes                    4                   3
# 5   1905602711267225794         yes                    5                   4
# 6   1905688085863825629         yes                    5                   4
# 7   1905948997447012406         yes                    4                   3
# 8   1908205717053706602         yes                    4                   3
# 9   1908291878048469170         yes                    4                   3
# 10  1910762452263841903         yes                    5                   4
# ...

# %%
df['is_trolling'].value_counts()
# Out:
# is_trolling
# yes    38039
# Name: count, dtype: int64
