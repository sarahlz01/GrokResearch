# %%
import seaborn as sn
import pandas as pd

# %%
df = pd.read_csv("/home/gbemike/Documents/github/GrokResearch/outputs/discussion_analysis_results/discussions_merged_results.csv")

# %%
df.head()
# Out:
#         conversationId is_discussion  discussion_confidence  \
# 0  1902090594723455088           yes                      5
# 1  1919142082666533245           yes                      4
# 2  1921799527368995057           yes                      5
# 3  1923426615448473840           yes                      5
# 4  1923744597773094942           yes                      5
#
#    discussion_intensity                       discussion_type  \
# 0                     2                             technical
# 1                     1  political, ethical, economic, social
# 2                     2                  political, technical
# 3                     2             political, ethical, legal
# 4                     2        political, ethical, historical
#
#                              topic bias_language  \
# 0        ai_responses_and_training           yes
# 1              colonialism_impacts           yes
# 2  tissue_discoloration_conspiracy           yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69820 entries, 0 to 69819
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   conversationId            69820 non-null  int64
#  1   is_discussion             69820 non-null  object
#  2   discussion_confidence     69820 non-null  int64
#  3   discussion_intensity      69820 non-null  int64
#  4   discussion_type           69820 non-null  object
#  5   topic                     69820 non-null  object
#  6   bias_language             69741 non-null  object
#  7   bias_examples             30963 non-null  object
#  8   bias_confidence           69741 non-null  float64
#  9   assistant_bias            69741 non-null  object
#  10  bias_intensity            69741 non-null  float64
#  11  assistant_stance          69741 non-null  object
#  12  stance_confidence         69741 non-null  float64
# ...

# %%
df[df['bias_language'] == 'yes']
# Out:
#             conversationId is_discussion  discussion_confidence  \
# 0      1902090594723455088           yes                      5
# 1      1919142082666533245           yes                      4
# 2      1921799527368995057           yes                      5
# 4      1923744597773094942           yes                      5
# 5      1941575159225147702           yes                      5
# ...                    ...           ...                    ...
# 69809  1975146805596664067           yes                      5
# 69812  1975149163894731014           yes                      5
# 69813  1975150946876334568           yes                      5
# 69815  1975152029736775827           yes                      3
# 69819  1975154334733140345           yes                      5
#
#        discussion_intensity                       discussion_type  \
# 0                         2                             technical
# ...
