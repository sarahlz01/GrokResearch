# %%
import seaborn as sn
import pandas as pd

# %%
df = pd.read_csv("/home/gbemike/Documents/github/GrokResearch/outputs/discussion_analysis_results/merged_results.csv")

# %%
df.head()
# Out:
#         conversationId is_discussion  discussion_confidence  \
# 0  1907794811874103754            no                      5
# 1  1907795373894103494           yes                      3
# 2  1907795676840284307            no                      2
# 3  1907796183088591184           yes                      3
# 4  1907797561525600491           yes                      4
#
#    discussion_intensity  discussion_type                            topic  \
# 0                     0              NaN             house_identification
# 1                     1              NaN       fried_pizza_health_effects
# 2                     0              NaN             dealing_with_insults
# 3                     1              NaN  trump_blackrock_eth_acquisition
# 4                     1              NaN           bitcoin_mining_tariffs
#
#   bias_language bias_examples  bias_confidence assistant_bias  bias_intensity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104089 entries, 0 to 104088
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   conversationId            104089 non-null  int64
#  1   is_discussion             104089 non-null  object
#  2   discussion_confidence     104089 non-null  int64
#  3   discussion_intensity      104089 non-null  int64
#  4   discussion_type           0 non-null       float64
#  5   topic                     104089 non-null  object
#  6   bias_language             47729 non-null   object
#  7   bias_examples             20774 non-null   object
#  8   bias_confidence           47729 non-null   float64
#  9   assistant_bias            47729 non-null   object
#  10  bias_intensity            47729 non-null   float64
#  11  assistant_stance          47729 non-null   object
#  12  stance_confidence         47729 non-null   float64
# ...

# %%
df[df['bias_language'] == 'yes']
# Out:
#              conversationId is_discussion  discussion_confidence  \
# 6       1907800279573205317           yes                      5
# 23      1907807373286064513           yes                      5
# 24      1907807932739359100           yes                      5
# 32      1907811579376119883           yes                      5
# 43      1907815808224604258           yes                      4
# ...                     ...           ...                    ...
# 104071  1973171967865004192           yes                      5
# 104074  1973174156725461480           yes                      5
# 104076  1973177941128520023           yes                      5
# 104080  1973179988242284720           yes                      5
# 104081  1973180270691107149           yes                      5
#
#         discussion_intensity  discussion_type  \
# 6                          2              NaN
# 23                         2              NaN
# ...
